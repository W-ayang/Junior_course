% %%
x = linspace(-4,4,50);
y = linspace(-4,4,50);
[X,Y] = meshgrid(x,y);

% %%
f = @(u,v)  u.^2 + 2 * v.^2;

% %%
norm(Z - X.^2 - 2 * Y.^2 , 'fro');

% %%
fid = 0;

% %%
fid = fid + 1
figure(fid);
clf
mesh(X,Y,Z);
% Out:
% fid =
%
%      1

% %%
%% 等高线
% contour(X,Y,Z);
contour(X,Y,Z,'ShowText', 'on', 'LevelStep', 10);

hold on;

% %%
startPosition = [-4 -4]

contour(X, Y, Z, 'ShowText', 'on', 'LevelStep', 10)
hold on;
plot(startPosition(1), startPosition(2), 'r.', 'MarkerSize', 10)
hold on
% Out:
% startPosition =
%
%     -4    -4

% %%
Z = f(X,Y);
size(Z)
% Out:
% ans =
%
%     50    50

% %%
x0 = [-4 4]
% Out:
% x0 =
%
%     -4     4

% %%
fun = @(p) p(:,1).^2 +p(:,2).^2;
